# %%
from plot4d import plotter

# %%
plotter.plot4d_CS(lambda x, y, z: 2*x**2+y+z, 10)

# %%
plotter.plot4d(lambda x, y, z: x**2+x*y+y**0.5+3*z-3*y*z, [0,1,2], save_images=False, func_name="test")
# Out:
# 'test.gif'
