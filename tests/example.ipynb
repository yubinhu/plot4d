# %%
from plot4d import plotter

# %%
plotter.plot4d_CS(lambda x, y, z: x+y+z, 10)
# Out:
# 'Figures/Crosssection at z=10.00.png'

# %%
plotter.plot4d(lambda x, y, z: x+y+z, [0,1,2], wbounds=(0, 5), save_images=False)
# Out:
# 'Cross Sections.gif'
